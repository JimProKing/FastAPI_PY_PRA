# %%
def introduce(name:str,age:int,city:str):
    print(f"it's {name}, {age} yrs old,. and live in {city}")

introduce("jim",28,"korea")
# Out:
# it's jim, 28 yrs old,. and live in korea

# %%
me = {
    "name":"jim",
    "age":28,
    #"city":"korea"
}

introduce(**me)
